# %%
# import libraries
import requests
import json
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# set the url for the data
a_url = "https://data.cdc.gov/resource/uc9k-vc2j.json"

# %%
# set the parameters for the data
limit = 1000000
offset = 0 
params = {"$limit": limit, "$offset": offset}

# get the data
response = requests.get(a_url, params=params)
data = response.json()
data
# Out:
# [{'locationid': '01001',
#   'year': '2000',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'data_value_footnote_symbol': '~',
#   'data_value_footnote': 'Value suppressed',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'American Indian and Alaska Native',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2001',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'data_value_footnote_symbol': '~',
#   'data_value_footnote': 'Value suppressed',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'American Indian and Alaska Native',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2002',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'data_value_footnote_symbol': '~',
#   'data_value_footnote': 'Value suppressed',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'American Indian and Alaska Native',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2003',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'data_value_footnote_symbol': '~',
#   'data_value_footnote': 'Value suppressed',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'American Indian and Alaska Native',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2004',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'data_value_footnote_symbol': '~',
#   'data_value_footnote': 'Value suppressed',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'American Indian and Alaska Native',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2005',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'data_value_footnote_symbol': '~',
#   'data_value_footnote': 'Value suppressed',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'American Indian and Alaska Native',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2006',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'data_value_footnote_symbol': '~',
#   'data_value_footnote': 'Value suppressed',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'American Indian and Alaska Native',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2007',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'data_value_footnote_symbol': '~',
#   'data_value_footnote': 'Value suppressed',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'American Indian and Alaska Native',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2008',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'data_value_footnote_symbol': '~',
#   'data_value_footnote': 'Value suppressed',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'American Indian and Alaska Native',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2009',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'data_value_footnote_symbol': '~',
#   'data_value_footnote': 'Value suppressed',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'American Indian and Alaska Native',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2010',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'data_value_footnote_symbol': '~',
#   'data_value_footnote': 'Value suppressed',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'American Indian and Alaska Native',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2011',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'data_value_footnote_symbol': '~',
#   'data_value_footnote': 'Value suppressed',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'American Indian and Alaska Native',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2012',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'data_value_footnote_symbol': '~',
#   'data_value_footnote': 'Value suppressed',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'American Indian and Alaska Native',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2013',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'data_value_footnote_symbol': '~',
#   'data_value_footnote': 'Value suppressed',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'American Indian and Alaska Native',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2014',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'data_value_footnote_symbol': '~',
#   'data_value_footnote': 'Value suppressed',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'American Indian and Alaska Native',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2015',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'data_value_footnote_symbol': '~',
#   'data_value_footnote': 'Value suppressed',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'American Indian and Alaska Native',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2016',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'data_value_footnote_symbol': '~',
#   'data_value_footnote': 'Value suppressed',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'American Indian and Alaska Native',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2017',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'data_value_footnote_symbol': '~',
#   'data_value_footnote': 'Value suppressed',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'American Indian and Alaska Native',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2018',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'data_value_footnote_symbol': '~',
#   'data_value_footnote': 'Value suppressed',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'American Indian and Alaska Native',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2019',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'data_value_footnote_symbol': '~',
#   'data_value_footnote': 'Value suppressed',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'American Indian and Alaska Native',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2000-2010',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value_unit': '%',
#   'data_value_type': 'Total percent change',
#   'data_value_footnote_symbol': '~',
#   'data_value_footnote': 'Value suppressed',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'American Indian and Alaska Native',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2010-2019',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value_unit': '%',
#   'data_value_type': 'Total percent change',
#   'data_value_footnote_symbol': '~',
#   'data_value_footnote': 'Value suppressed',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'American Indian and Alaska Native',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2000',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'data_value_footnote_symbol': '~',
#   'data_value_footnote': 'Value suppressed',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Asian and Pacific Islander',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2001',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'data_value_footnote_symbol': '~',
#   'data_value_footnote': 'Value suppressed',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Asian and Pacific Islander',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2002',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'data_value_footnote_symbol': '~',
#   'data_value_footnote': 'Value suppressed',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Asian and Pacific Islander',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2003',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'data_value_footnote_symbol': '~',
#   'data_value_footnote': 'Value suppressed',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Asian and Pacific Islander',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2004',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'data_value_footnote_symbol': '~',
#   'data_value_footnote': 'Value suppressed',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Asian and Pacific Islander',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2005',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'data_value_footnote_symbol': '~',
#   'data_value_footnote': 'Value suppressed',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Asian and Pacific Islander',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2006',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'data_value_footnote_symbol': '~',
#   'data_value_footnote': 'Value suppressed',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Asian and Pacific Islander',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2007',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'data_value_footnote_symbol': '~',
#   'data_value_footnote': 'Value suppressed',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Asian and Pacific Islander',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2008',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'data_value_footnote_symbol': '~',
#   'data_value_footnote': 'Value suppressed',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Asian and Pacific Islander',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2009',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'data_value_footnote_symbol': '~',
#   'data_value_footnote': 'Value suppressed',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Asian and Pacific Islander',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2010',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'data_value_footnote_symbol': '~',
#   'data_value_footnote': 'Value suppressed',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Asian and Pacific Islander',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2011',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'data_value_footnote_symbol': '~',
#   'data_value_footnote': 'Value suppressed',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Asian and Pacific Islander',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2012',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'data_value_footnote_symbol': '~',
#   'data_value_footnote': 'Value suppressed',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Asian and Pacific Islander',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2013',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'data_value_footnote_symbol': '~',
#   'data_value_footnote': 'Value suppressed',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Asian and Pacific Islander',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2014',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'data_value_footnote_symbol': '~',
#   'data_value_footnote': 'Value suppressed',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Asian and Pacific Islander',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2015',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'data_value_footnote_symbol': '~',
#   'data_value_footnote': 'Value suppressed',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Asian and Pacific Islander',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2016',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'data_value_footnote_symbol': '~',
#   'data_value_footnote': 'Value suppressed',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Asian and Pacific Islander',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2017',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'data_value_footnote_symbol': '~',
#   'data_value_footnote': 'Value suppressed',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Asian and Pacific Islander',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2018',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'data_value_footnote_symbol': '~',
#   'data_value_footnote': 'Value suppressed',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Asian and Pacific Islander',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2019',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'data_value_footnote_symbol': '~',
#   'data_value_footnote': 'Value suppressed',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Asian and Pacific Islander',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2000-2010',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value_unit': '%',
#   'data_value_type': 'Total percent change',
#   'data_value_footnote_symbol': '~',
#   'data_value_footnote': 'Value suppressed',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Asian and Pacific Islander',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2010-2019',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value_unit': '%',
#   'data_value_type': 'Total percent change',
#   'data_value_footnote_symbol': '~',
#   'data_value_footnote': 'Value suppressed',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Asian and Pacific Islander',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2000',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value': '76.9',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'confidence_limit_low': '61.5',
#   'confidence_limit_high': '99.6',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Black',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2001',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value': '83.4',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'confidence_limit_low': '69',
#   'confidence_limit_high': '126.7',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Black',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2002',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value': '86.2',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'confidence_limit_low': '66.7',
#   'confidence_limit_high': '122.1',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Black',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2003',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value': '81.6',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'confidence_limit_low': '58.5',
#   'confidence_limit_high': '117',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Black',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2004',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value': '84.7',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'confidence_limit_low': '63.7',
#   'confidence_limit_high': '114.6',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Black',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2005',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value': '94.7',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'confidence_limit_low': '70.3',
#   'confidence_limit_high': '121',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Black',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2006',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value': '99.4',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'confidence_limit_low': '75.4',
#   'confidence_limit_high': '126.1',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Black',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2007',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value': '80.7',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'confidence_limit_low': '63.4',
#   'confidence_limit_high': '102',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Black',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2008',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value': '76.7',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'confidence_limit_low': '58.2',
#   'confidence_limit_high': '98.9',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Black',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2009',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value': '77.9',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'confidence_limit_low': '58.1',
#   'confidence_limit_high': '95.7',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Black',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2010',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value': '73.5',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'confidence_limit_low': '57.8',
#   'confidence_limit_high': '92',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Black',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2011',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value': '79.3',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'confidence_limit_low': '65',
#   'confidence_limit_high': '99.3',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Black',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2012',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value': '82.6',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'confidence_limit_low': '67.9',
#   'confidence_limit_high': '99.6',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Black',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2013',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value': '84.6',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'confidence_limit_low': '70.6',
#   'confidence_limit_high': '104.2',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Black',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2014',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value': '89.3',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'confidence_limit_low': '69.7',
#   'confidence_limit_high': '110.2',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Black',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2015',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value': '86.7',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'confidence_limit_low': '63.5',
#   'confidence_limit_high': '109.1',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Black',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2016',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value': '82',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'confidence_limit_low': '62.2',
#   'confidence_limit_high': '102.2',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Black',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2017',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value': '81.6',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'confidence_limit_low': '64.3',
#   'confidence_limit_high': '98.6',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Black',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2018',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value': '81.5',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'confidence_limit_low': '66.3',
#   'confidence_limit_high': '100.3',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Black',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Overall',
#   'topicid': 'T1',
#   'x_long': '-86.64295911',
#   'y_lat': '32.53530561'},
#  {'locationid': '01001',
#   'year': '2019',
#   'locationabbr': 'AL',
#   'locationdesc': 'Autauga',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value': '76.2',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'confidence_limit_low': '61.1',
#   'confidence_limit_high': '95.3',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 35-64 years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Black',
# ...
#   'confidence_limit_low': '308.5',
#   'confidence_limit_high': '444.7',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 65+ years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Overall',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Female',
#   'topicid': 'T1',
#   'x_long': '-85.39257759',
#   'y_lat': '31.86971146'},
#  {'locationid': '01005',
#   'year': '2005',
#   'locationabbr': 'AL',
#   'locationdesc': 'Barbour',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value': '380.3',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'confidence_limit_low': '302',
#   'confidence_limit_high': '457',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 65+ years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Overall',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Female',
#   'topicid': 'T1',
#   'x_long': '-85.39257759',
#   'y_lat': '31.86971146'},
#  {'locationid': '01005',
#   'year': '2006',
#   'locationabbr': 'AL',
#   'locationdesc': 'Barbour',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value': '370.6',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'confidence_limit_low': '305',
#   'confidence_limit_high': '469.2',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 65+ years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Overall',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Female',
#   'topicid': 'T1',
#   'x_long': '-85.39257759',
#   'y_lat': '31.86971146'},
#  {'locationid': '01005',
#   'year': '2007',
#   'locationabbr': 'AL',
#   'locationdesc': 'Barbour',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value': '358.2',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'confidence_limit_low': '306.1',
#   'confidence_limit_high': '414.2',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 65+ years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Overall',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Female',
#   'topicid': 'T1',
#   'x_long': '-85.39257759',
#   'y_lat': '31.86971146'},
#  {'locationid': '01005',
#   'year': '2008',
#   'locationabbr': 'AL',
#   'locationdesc': 'Barbour',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value': '335.9',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'confidence_limit_low': '284.7',
#   'confidence_limit_high': '415.9',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 65+ years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Overall',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Female',
#   'topicid': 'T1',
#   'x_long': '-85.39257759',
#   'y_lat': '31.86971146'},
#  {'locationid': '01005',
#   'year': '2009',
#   'locationabbr': 'AL',
#   'locationdesc': 'Barbour',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value': '334.4',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'confidence_limit_low': '275.6',
#   'confidence_limit_high': '422.1',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 65+ years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Overall',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Female',
#   'topicid': 'T1',
#   'x_long': '-85.39257759',
#   'y_lat': '31.86971146'},
#  {'locationid': '01005',
#   'year': '2010',
#   'locationabbr': 'AL',
#   'locationdesc': 'Barbour',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value': '349.6',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'confidence_limit_low': '289.2',
#   'confidence_limit_high': '432.2',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 65+ years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Overall',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Female',
#   'topicid': 'T1',
#   'x_long': '-85.39257759',
#   'y_lat': '31.86971146'},
#  {'locationid': '01005',
#   'year': '2011',
#   'locationabbr': 'AL',
#   'locationdesc': 'Barbour',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value': '321.9',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'confidence_limit_low': '267.9',
#   'confidence_limit_high': '399.3',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 65+ years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Overall',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Female',
#   'topicid': 'T1',
#   'x_long': '-85.39257759',
#   'y_lat': '31.86971146'},
#  {'locationid': '01005',
#   'year': '2012',
#   'locationabbr': 'AL',
#   'locationdesc': 'Barbour',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value': '320.1',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'confidence_limit_low': '259.5',
#   'confidence_limit_high': '377.8',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 65+ years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Overall',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Female',
#   'topicid': 'T1',
#   'x_long': '-85.39257759',
#   'y_lat': '31.86971146'},
#  {'locationid': '01005',
#   'year': '2013',
#   'locationabbr': 'AL',
#   'locationdesc': 'Barbour',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value': '315.3',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'confidence_limit_low': '266',
#   'confidence_limit_high': '371.1',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 65+ years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Overall',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Female',
#   'topicid': 'T1',
#   'x_long': '-85.39257759',
#   'y_lat': '31.86971146'},
#  {'locationid': '01005',
#   'year': '2014',
#   'locationabbr': 'AL',
#   'locationdesc': 'Barbour',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value': '275.3',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'confidence_limit_low': '238.2',
#   'confidence_limit_high': '333.8',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 65+ years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Overall',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Female',
#   'topicid': 'T1',
#   'x_long': '-85.39257759',
#   'y_lat': '31.86971146'},
#  {'locationid': '01005',
#   'year': '2015',
#   'locationabbr': 'AL',
#   'locationdesc': 'Barbour',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value': '262.7',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'confidence_limit_low': '219.2',
#   'confidence_limit_high': '315',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 65+ years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Overall',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Female',
#   'topicid': 'T1',
#   'x_long': '-85.39257759',
#   'y_lat': '31.86971146'},
#  {'locationid': '01005',
#   'year': '2016',
#   'locationabbr': 'AL',
#   'locationdesc': 'Barbour',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value': '274',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'confidence_limit_low': '215',
#   'confidence_limit_high': '329.1',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 65+ years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Overall',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Female',
#   'topicid': 'T1',
#   'x_long': '-85.39257759',
#   'y_lat': '31.86971146'},
#  {'locationid': '01005',
#   'year': '2017',
#   'locationabbr': 'AL',
#   'locationdesc': 'Barbour',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value': '284.6',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'confidence_limit_low': '236.1',
#   'confidence_limit_high': '350.5',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 65+ years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Overall',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Female',
#   'topicid': 'T1',
#   'x_long': '-85.39257759',
#   'y_lat': '31.86971146'},
#  {'locationid': '01005',
#   'year': '2018',
#   'locationabbr': 'AL',
#   'locationdesc': 'Barbour',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value': '331.4',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'confidence_limit_low': '273.5',
#   'confidence_limit_high': '393.8',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 65+ years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Overall',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Female',
#   'topicid': 'T1',
#   'x_long': '-85.39257759',
#   'y_lat': '31.86971146'},
#  {'locationid': '01005',
#   'year': '2019',
#   'locationabbr': 'AL',
#   'locationdesc': 'Barbour',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value': '341',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'confidence_limit_low': '276.5',
#   'confidence_limit_high': '427.9',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 65+ years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Overall',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Female',
#   'topicid': 'T1',
#   'x_long': '-85.39257759',
#   'y_lat': '31.86971146'},
#  {'locationid': '01005',
#   'year': '2000-2010',
#   'locationabbr': 'AL',
#   'locationdesc': 'Barbour',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value': '-5.6',
#   'data_value_unit': '%',
#   'data_value_type': 'Total percent change',
#   'confidence_limit_low': '-26.6',
#   'confidence_limit_high': '22.5',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 65+ years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Overall',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Female',
#   'topicid': 'T1',
#   'x_long': '-85.39257759',
#   'y_lat': '31.86971146'},
#  {'locationid': '01005',
#   'year': '2010-2019',
#   'locationabbr': 'AL',
#   'locationdesc': 'Barbour',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value': '-4.9',
#   'data_value_unit': '%',
#   'data_value_type': 'Total percent change',
#   'confidence_limit_low': '-28.7',
#   'confidence_limit_high': '18.6',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 65+ years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Overall',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Female',
#   'topicid': 'T1',
#   'x_long': '-85.39257759',
#   'y_lat': '31.86971146'},
#  {'locationid': '01005',
#   'year': '2000',
#   'locationabbr': 'AL',
#   'locationdesc': 'Barbour',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value': '345.7',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'confidence_limit_low': '285.8',
#   'confidence_limit_high': '436.6',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 65+ years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Overall',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Male',
#   'topicid': 'T1',
#   'x_long': '-85.39257759',
#   'y_lat': '31.86971146'},
#  {'locationid': '01005',
#   'year': '2001',
#   'locationabbr': 'AL',
#   'locationdesc': 'Barbour',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value': '356.1',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'confidence_limit_low': '291.3',
#   'confidence_limit_high': '420.1',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 65+ years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Overall',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Male',
#   'topicid': 'T1',
#   'x_long': '-85.39257759',
#   'y_lat': '31.86971146'},
#  {'locationid': '01005',
#   'year': '2002',
#   'locationabbr': 'AL',
#   'locationdesc': 'Barbour',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value': '365.8',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'confidence_limit_low': '302.4',
#   'confidence_limit_high': '440',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 65+ years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Overall',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Male',
#   'topicid': 'T1',
#   'x_long': '-85.39257759',
#   'y_lat': '31.86971146'},
#  {'locationid': '01005',
#   'year': '2003',
#   'locationabbr': 'AL',
#   'locationdesc': 'Barbour',
#   'geographiclevel': 'County',
#   'datasource': 'NVSS',
#   'class': 'Cardiovascular Diseases',
#   'topic': 'Major Cardiovascular Disease',
#   'data_value': '364.6',
#   'data_value_unit': 'per 100,000',
#   'data_value_type': 'Age-Standardized, Spatiotemporally Smoothed Rate',
#   'confidence_limit_low': '302.4',
#   'confidence_limit_high': '430.8',
#   'stratificationcategory1': 'Age group',
#   'stratification1': 'Ages 65+ years',
#   'stratificationcategory2': 'Race/EthnicityAge group',
#   'stratification2': 'Overall',
#   'stratificationcategory3': 'Sex',
#   'stratification3': 'Male',
#   'topicid': 'T1',
#   'x_long': '-85.39257759',
#   'y_lat': '31.86971146'},
#  ...]

# %%
# convert the data to a dataframe
df = pd.DataFrame(data)
df
# Out:
#        locationid       year locationabbr locationdesc geographiclevel  \
# 0           01001       2000           AL      Autauga          County
# 1           01001       2001           AL      Autauga          County
# 2           01001       2002           AL      Autauga          County
# 3           01001       2003           AL      Autauga          County
# 4           01001       2004           AL      Autauga          County
# ...           ...        ...          ...          ...             ...
# 999995      51053       2019           VA    Dinwiddie          County
# 999996      51053  2000-2010           VA    Dinwiddie          County
# 999997      51053  2010-2019           VA    Dinwiddie          County
# 999998      51053       2000           VA    Dinwiddie          County
# 999999      51053       2001           VA    Dinwiddie          County
#
#        datasource                    class                         topic  \
# 0            NVSS  Cardiovascular Diseases  Major Cardiovascular Disease
# 1            NVSS  Cardiovascular Diseases  Major Cardiovascular Disease
# 2            NVSS  Cardiovascular Diseases  Major Cardiovascular Disease
# 3            NVSS  Cardiovascular Diseases  Major Cardiovascular Disease
# 4            NVSS  Cardiovascular Diseases  Major Cardiovascular Disease
# ...           ...                      ...                           ...
# 999995       NVSS  Cardiovascular Diseases  Major Cardiovascular Disease
# 999996       NVSS  Cardiovascular Diseases  Major Cardiovascular Disease
# 999997       NVSS  Cardiovascular Diseases  Major Cardiovascular Disease
# 999998       NVSS  Cardiovascular Diseases  Major Cardiovascular Disease
# 999999       NVSS  Cardiovascular Diseases  Major Cardiovascular Disease
#
#        data_value_unit                                   data_value_type  ...  \
# 0          per 100,000  Age-Standardized, Spatiotemporally Smoothed Rate  ...
# 1          per 100,000  Age-Standardized, Spatiotemporally Smoothed Rate  ...
# 2          per 100,000  Age-Standardized, Spatiotemporally Smoothed Rate  ...
# 3          per 100,000  Age-Standardized, Spatiotemporally Smoothed Rate  ...
# 4          per 100,000  Age-Standardized, Spatiotemporally Smoothed Rate  ...
# ...                ...                                               ...  ...
# 999995     per 100,000  Age-Standardized, Spatiotemporally Smoothed Rate  ...
# 999996               %                              Total percent change  ...
# 999997               %                              Total percent change  ...
# 999998     per 100,000  Age-Standardized, Spatiotemporally Smoothed Rate  ...
# 999999     per 100,000  Age-Standardized, Spatiotemporally Smoothed Rate  ...
#
#         stratificationcategory2                    stratification2  \
# 0       Race/EthnicityAge group  American Indian and Alaska Native
# 1       Race/EthnicityAge group  American Indian and Alaska Native
# 2       Race/EthnicityAge group  American Indian and Alaska Native
# 3       Race/EthnicityAge group  American Indian and Alaska Native
# 4       Race/EthnicityAge group  American Indian and Alaska Native
# ...                         ...                                ...
# 999995  Race/EthnicityAge group                           Hispanic
# 999996  Race/EthnicityAge group                           Hispanic
# 999997  Race/EthnicityAge group                           Hispanic
# 999998  Race/EthnicityAge group                            Overall
# 999999  Race/EthnicityAge group                            Overall
#
#        stratificationcategory3 stratification3 topicid        x_long  \
# 0                          Sex         Overall      T1  -86.64295911
# 1                          Sex         Overall      T1  -86.64295911
# 2                          Sex         Overall      T1  -86.64295911
# 3                          Sex         Overall      T1  -86.64295911
# 4                          Sex         Overall      T1  -86.64295911
# ...                        ...             ...     ...           ...
# 999995                     Sex         Overall      T1  -77.63220543
# 999996                     Sex         Overall      T1  -77.63220543
# 999997                     Sex         Overall      T1  -77.63220543
# 999998                     Sex          Female      T1  -77.63220543
# 999999                     Sex          Female      T1  -77.63220543
#
#               y_lat data_value confidence_limit_low confidence_limit_high
# 0       32.53530561        NaN                  NaN                   NaN
# 1       32.53530561        NaN                  NaN                   NaN
# 2       32.53530561        NaN                  NaN                   NaN
# 3       32.53530561        NaN                  NaN                   NaN
# 4       32.53530561        NaN                  NaN                   NaN
# ...             ...        ...                  ...                   ...
# 999995   37.0760146        NaN                  NaN                   NaN
# 999996   37.0760146        NaN                  NaN                   NaN
# 999997   37.0760146        NaN                  NaN                   NaN
# 999998   37.0760146      433.1                342.3                 525.8
# 999999   37.0760146        453                347.3                 557.2
#
# [1000000 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['locationid', 'year', 'locationabbr', 'locationdesc', 'geographiclevel',
#        'datasource', 'class', 'topic', 'data_value_unit', 'data_value_type',
#        'data_value_footnote_symbol', 'data_value_footnote',
#        'stratificationcategory1', 'stratification1', 'stratificationcategory2',
#        'stratification2', 'stratificationcategory3', 'stratification3',
#        'topicid', 'x_long', 'y_lat', 'data_value', 'confidence_limit_low',
#        'confidence_limit_high'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count    Dtype
# ---  ------                      --------------    -----
#  0   locationid                  1000000 non-null  object
#  1   year                        1000000 non-null  object
#  2   locationabbr                1000000 non-null  object
#  3   locationdesc                1000000 non-null  object
#  4   geographiclevel             1000000 non-null  object
#  5   datasource                  1000000 non-null  object
#  6   class                       1000000 non-null  object
#  7   topic                       1000000 non-null  object
#  8   data_value_unit             1000000 non-null  object
#  9   data_value_type             1000000 non-null  object
#  10  data_value_footnote_symbol  480018 non-null   object
#  11  data_value_footnote         480018 non-null   object
#  12  stratificationcategory1     1000000 non-null  object
#  13  stratification1             1000000 non-null  object
#  14  stratificationcategory2     1000000 non-null  object
#  15  stratification2             1000000 non-null  object
#  16  stratificationcategory3     1000000 non-null  object
#  17  stratification3             1000000 non-null  object
#  18  topicid                     1000000 non-null  object
#  19  x_long                      1000000 non-null  object
#  20  y_lat                       1000000 non-null  object
#  21  data_value                  519982 non-null   object
#  22  confidence_limit_low        519982 non-null   object
#  23  confidence_limit_high       519982 non-null   object
# dtypes: object(24)
# memory usage: 183.1+ MB

# %%
# check missing values
df.isnull().sum()
# Out:
# locationid                         0
# year                               0
# locationabbr                       0
# locationdesc                       0
# geographiclevel                    0
# datasource                         0
# class                              0
# topic                              0
# data_value_unit                    0
# data_value_type                    0
# data_value_footnote_symbol    519982
# data_value_footnote           519982
# stratificationcategory1            0
# stratification1                    0
# stratificationcategory2            0
# stratification2                    0
# stratificationcategory3            0
# stratification3                    0
# topicid                            0
# x_long                             0
# y_lat                              0
# data_value                    480018
# confidence_limit_low          480018
# confidence_limit_high         480018
# dtype: int64

# %%
df = df.dropna(subset=['data_value'])

# %%
df = df.drop(columns=['geographiclevel', 'datasource', 'class', 'topic', 'data_value_footnote_symbol', 'data_value_footnote', 'stratificationcategory1', 'stratificationcategory2', 'stratificationcategory3', 'topicid'])
df

# %%
column_names = {'stratification1': 'age_group', 'stratification2': 'race/ethnicityage_group', 'stratification3': 'sex'}
df = df.rename(columns=column_names)
df
# Out:
#        locationid       year locationabbr locationdesc data_value_unit  \
# 44          01001       2000           AL      Autauga     per 100,000
# 45          01001       2001           AL      Autauga     per 100,000
# 46          01001       2002           AL      Autauga     per 100,000
# 47          01001       2003           AL      Autauga     per 100,000
# 48          01001       2004           AL      Autauga     per 100,000
# ...           ...        ...          ...          ...             ...
# 999973      51053       2019           VA    Dinwiddie     per 100,000
# 999974      51053  2000-2010           VA    Dinwiddie               %
# 999975      51053  2010-2019           VA    Dinwiddie               %
# 999998      51053       2000           VA    Dinwiddie     per 100,000
# 999999      51053       2001           VA    Dinwiddie     per 100,000
#
#                                          data_value_type         age_group  \
# 44      Age-Standardized, Spatiotemporally Smoothed Rate  Ages 35-64 years
# 45      Age-Standardized, Spatiotemporally Smoothed Rate  Ages 35-64 years
# 46      Age-Standardized, Spatiotemporally Smoothed Rate  Ages 35-64 years
# 47      Age-Standardized, Spatiotemporally Smoothed Rate  Ages 35-64 years
# 48      Age-Standardized, Spatiotemporally Smoothed Rate  Ages 35-64 years
# ...                                                  ...               ...
# 999973  Age-Standardized, Spatiotemporally Smoothed Rate    Ages 65+ years
# 999974                              Total percent change    Ages 65+ years
# 999975                              Total percent change    Ages 65+ years
# 999998  Age-Standardized, Spatiotemporally Smoothed Rate    Ages 65+ years
# 999999  Age-Standardized, Spatiotemporally Smoothed Rate    Ages 65+ years
#
#        race/ethnicityage_group      sex        x_long        y_lat data_value  \
# 44                       Black  Overall  -86.64295911  32.53530561       76.9
# 45                       Black  Overall  -86.64295911  32.53530561       83.4
# 46                       Black  Overall  -86.64295911  32.53530561       86.2
# 47                       Black  Overall  -86.64295911  32.53530561       81.6
# 48                       Black  Overall  -86.64295911  32.53530561       84.7
# ...                        ...      ...           ...          ...        ...
# 999973                   Black  Overall  -77.63220543   37.0760146      334.5
# 999974                   Black  Overall  -77.63220543   37.0760146        -14
# 999975                   Black  Overall  -77.63220543   37.0760146        -13
# 999998                 Overall   Female  -77.63220543   37.0760146      433.1
# 999999                 Overall   Female  -77.63220543   37.0760146        453
#
#        confidence_limit_low confidence_limit_high
# 44                     61.5                  99.6
# 45                       69                 126.7
# 46                     66.7                 122.1
# 47                     58.5                   117
# 48                     63.7                 114.6
# ...                     ...                   ...
# 999973                272.5                 459.4
# 999974                -39.8                  14.8
# 999975                -34.6                  20.1
# 999998                342.3                 525.8
# 999999                347.3                 557.2
#
# [519982 rows x 14 columns]

# %%
total_percent_df = df[df['data_value_type'] == 'Total percent change'] 
total_percent_df = total_percent_df.drop(columns=['data_value_type', 'data_value_unit'])
total_percent_df.reset_index(drop=True, inplace=True)
total_percent_df
# Out:
#       locationid       year locationabbr locationdesc         age_group  \
# 0          01001  2000-2010           AL      Autauga  Ages 35-64 years
# 1          01001  2010-2019           AL      Autauga  Ages 35-64 years
# 2          01001  2000-2010           AL      Autauga  Ages 35-64 years
# 3          01001  2010-2019           AL      Autauga  Ages 35-64 years
# 4          01001  2000-2010           AL      Autauga  Ages 35-64 years
# ...          ...        ...          ...          ...               ...
# 47295      51053  2010-2019           VA    Dinwiddie  Ages 35-64 years
# 47296      51053  2000-2010           VA    Dinwiddie  Ages 35-64 years
# 47297      51053  2010-2019           VA    Dinwiddie  Ages 35-64 years
# 47298      51053  2000-2010           VA    Dinwiddie    Ages 65+ years
# 47299      51053  2010-2019           VA    Dinwiddie    Ages 65+ years
#
#       race/ethnicityage_group      sex        x_long        y_lat data_value  \
# 0                       Black  Overall  -86.64295911  32.53530561       -7.5
# 1                       Black  Overall  -86.64295911  32.53530561        2.6
# 2                     Overall   Female  -86.64295911  32.53530561       17.1
# 3                     Overall   Female  -86.64295911  32.53530561        8.3
# 4                     Overall     Male  -86.64295911  32.53530561       19.7
# ...                       ...      ...           ...          ...        ...
# 47295                 Overall  Overall  -77.63220543   37.0760146       20.4
# 47296                   White  Overall  -77.63220543   37.0760146      -20.1
# 47297                   White  Overall  -77.63220543   37.0760146       32.6
# 47298                   Black  Overall  -77.63220543   37.0760146        -14
# 47299                   Black  Overall  -77.63220543   37.0760146        -13
#
#       confidence_limit_low confidence_limit_high
# 0                    -37.7                  31.7
# 1                    -25.8                  31.2
# 2                    -19.8                  73.5
# 3                    -19.1                  62.1
# 4                    -10.2                    98
# ...                    ...                   ...
# 47295                 -9.6                  62.2
# 47296                -47.7                  50.3
# 47297                 -4.4                  99.1
# 47298                -39.8                  14.8
# 47299                -34.6                  20.1
#
# [47300 rows x 12 columns]

# %%
smoothed_rate_df = df[df['data_value_type'] == 'Age-Standardized, Spatiotemporally Smoothed Rate']
smoothed_rate_df = smoothed_rate_df.drop(columns=['data_value_type', 'data_value_unit'])
smoothed_rate_df.reset_index(drop=True, inplace=True)
smoothed_rate_df
# Out:
#        locationid  year locationabbr locationdesc         age_group  \
# 0           01001  2000           AL      Autauga  Ages 35-64 years
# 1           01001  2001           AL      Autauga  Ages 35-64 years
# 2           01001  2002           AL      Autauga  Ages 35-64 years
# 3           01001  2003           AL      Autauga  Ages 35-64 years
# 4           01001  2004           AL      Autauga  Ages 35-64 years
# ...           ...   ...          ...          ...               ...
# 472677      51053  2017           VA    Dinwiddie    Ages 65+ years
# 472678      51053  2018           VA    Dinwiddie    Ages 65+ years
# 472679      51053  2019           VA    Dinwiddie    Ages 65+ years
# 472680      51053  2000           VA    Dinwiddie    Ages 65+ years
# 472681      51053  2001           VA    Dinwiddie    Ages 65+ years
#
#        race/ethnicityage_group      sex        x_long        y_lat data_value  \
# 0                        Black  Overall  -86.64295911  32.53530561       76.9
# 1                        Black  Overall  -86.64295911  32.53530561       83.4
# 2                        Black  Overall  -86.64295911  32.53530561       86.2
# 3                        Black  Overall  -86.64295911  32.53530561       81.6
# 4                        Black  Overall  -86.64295911  32.53530561       84.7
# ...                        ...      ...           ...          ...        ...
# 472677                   Black  Overall  -77.63220543   37.0760146      338.8
# 472678                   Black  Overall  -77.63220543   37.0760146      321.9
# 472679                   Black  Overall  -77.63220543   37.0760146      334.5
# 472680                 Overall   Female  -77.63220543   37.0760146      433.1
# 472681                 Overall   Female  -77.63220543   37.0760146        453
#
#        confidence_limit_low confidence_limit_high
# 0                      61.5                  99.6
# 1                        69                 126.7
# 2                      66.7                 122.1
# 3                      58.5                   117
# 4                      63.7                 114.6
# ...                     ...                   ...
# 472677                  286                 402.8
# 472678                261.5                 415.1
# 472679                272.5                 459.4
# 472680                342.3                 525.8
# 472681                347.3                 557.2
#
# [472682 rows x 12 columns]

# %%
total_percent_df.to_csv('Data/total_percent_df.csv', index=False)
smoothed_rate_df.to_csv('Data/smoothed_rate_df.csv', index=False)
